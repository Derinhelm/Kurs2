# %%
from Types import *
from Functions import *
from prob import *

# %%
import postgresql

# %%
db = postgresql.open('pq://derin:qwerty@localhost:5432/models')

# %%
a1 = main(db, "Страх перед именем усиливает ужас пред тем, кто его носит.")

# %%
a2 = main(db, "Каждый час имеет своё чудо.")

# %%
a3 = main(db, "Ты стал очень хорошим человеком.")

# %%
a4 = main(db, "Мир не делится на плохих и хороших людей.")
# Out:
# No model
# Не разобрано!

# %%
a5 = main(db, "В каждом есть светлая и темная сторона.")
# Out:
# No model
# Не разобрано!

# %%
a5 = main(db, "Вещи, потерянные нами, обязательно вернутся к нам.")

# %%
Человека определяют не заложенные в нем качества, а только его выбор

# %%
Она умела видеть красоту в людях
