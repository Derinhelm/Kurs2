# %%
from Types import *
from Functions import *
from main import *

# %%
import postgresql

# %%
db = postgresql.open('pq://derin:qwerty@localhost:5432/models')

# %%
type(db)
# Out:
# postgresql.driver.pq3.Connection

# %%
a1 = parse(db, "Каждый час имеет своё чудо.", True)

# %%
a1[0].__dict__
# Out:
# {'childParsePoint': [],
#  'parsePointWordList': [<prob.ParsePointWord at 0x7fc152bd9668>,
# ...
#   <prob.ParsePointWord at 0x7fc152913a20>]}

# %%
s = Sentence()

# %%
s.__dict__
# Out:
# {'firstUse': True,
#  'inputStr': '',
#  'rootPP': <prob.ParsePoint at 0x7fc1508ad7b8>,
#  'wordList': []}

# %%
a1
# Out:
# (<prob.ParsePoint at 0x7fc15291d240>,
# ...
#   <prob.ParsePoint at 0x7fc15291d240>])

# %%
for i in a1[1]:
    i.visualizate()

# %%
a1.parsePointWordList[1].usedGp[0].model.__dict__
# Out:
# {'dependentWord': 'каждый',
#  'dependentWordConstraints': ['adjective', 'male', 'single', 'nominative'],
#  'info': '',
#  'level': 3,
#  'mark': 1.0,
#  'prep': 'None'}

# %%
a2 = main(db, "Ты стал очень хорошим человеком.")

# %%
a3 = main(db, "Мир не делится на плохих и хороших людей.")
# Out:
# No model
# Не разобрано!

# %%
a4 = main(db, "В каждом есть светлая и темная сторона.")
# Out:
# No model
# Не разобрано!

# %%
a5 = main(db, "Вещи, потерянные нами, обязательно вернутся к нам.")

# %%
a5.parsePointWordList[4].usedGp[0].__dict__
# Out:
# {'depWord': <prob.Word at 0x7fa9fc97d7f0>,
#  'level': 3,
#  'mark': 1.0,
#  'model': <prob.GPattern at 0x7fa9fc97d7b8>}

# %%
        str1 = input()
        s = Sentence()
        s.setString(str1)
        s.morfParse()
        s.getGPatterns()
        res = s.sintParse()
        res.visualizate()
        res1 = s.sintParse()
        res1.visualizate()
# Out:
# "Вещи, потерянные нами, обязательно вернутся к нам."

# %%
res1.__dict__
# Out:
# {'childParsePoint': [],
#  'parsePointWordList': [<prob.ParsePointWord at 0x7f33a3587278>,
# ...
#   <prob.ParsePointWord at 0x7f33a358ab00>]}

# %%
a6 = main(db, "Страх перед именем усиливает ужас пред тем, кто его носит.")

# %%
a6.parsePointWordList[0].usedGp[0].__dict__
# Out:
# {'depWord': <prob.Word at 0x7f4dca164240>,
#  'level': 3,
#  'mark': 1.0,
#  'model': <prob.GPattern at 0x7f4dca164208>}
