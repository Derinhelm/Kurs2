# %%
from Types import *
from Functions import *
from main import *

# %%
import postgresql

# %%
db = postgresql.open('pq://derin:qwerty@localhost:5432/models')

# %%
type(db)
# Out:
# postgresql.driver.pq3.Connection

# %%
a1 = parse(db, "Каждый час имеет своё чудо.", True)

# %%
a1[0].__dict__
# Out:
# {'childParsePoint': [],
#  'parsePointWordList': [<main.ParsePointWord at 0x7f5f75275a58>,
# ...
#   <main.ParsePointWord at 0x7f5f74facc18>]}

# %%
# Очевидно, что в итоговой точке childParsePoint = [], т.к. разбор закончен

# %%
a1[0].parsePointWordList[2].__dict__
# Out:
# {'isUsedPrep': <EUsedPrep.noPrep: 1>,
#  'parsed': True,
#  'usedGp': [<main.Gp at 0x7f5f74fac748>, <main.Gp at 0x7f5f74fac8d0>],
#  'usedMorfAnswer': <Types.Morf at 0x7f5f74fac470>,
#  'word': <main.Word at 0x7f5f74fac438>}

# %%
for i in a1[1]:
    i.visualizate()

# %%
a2 = parse(db, "Ты стал очень хорошим человеком.", False)

# %%
a3 = parse(db, "Мир не делится на плохих и хороших людей.")
# Out:
# No model
# Не разобрано!

# %%
a4 = parse(db, "В каждом есть светлая и темная сторона.")
# Out:
# No model
# Не разобрано!

# %%
a5 = parse(db, "Вещи, потерянные нами, обязательно вернутся к нам.")

# %%
a5.parsePointWordList[4].usedGp[0].__dict__
# Out:
# {'depWord': <main.Word at 0x7f5f72ce4fd0>,
#  'level': 3,
#  'mark': 1.0,
#  'model': <main.GPattern at 0x7f5f72c76048>}

# %%
a6 = parse(db, "Страх перед именем усиливает ужас пред тем, кто его носит.")

# %%
a6.parsePointWordList[0].usedGp[0].__dict__
# Out:
# {'depWord': <main.Word at 0x7f5f72c4acc0>,
#  'level': 3,
#  'mark': 1.0,
#  'model': <main.GPattern at 0x7f5f72c4acf8>}
