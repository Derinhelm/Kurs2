# %%
import postgresql

# %%
db = postgresql.open('pq://derin:qwerty@localhost:5432/models')

# %%
import pymorphy2
morph = pymorphy2.MorphAnalyzer()

# %%
from Types import *

# %%
from Functions import *

# %%
ЧЕРНОВИК!!!! Чистовик - см. Types

# %%
properties = {}

# %%
class PropertyPartSpeech:
    def __init__(self):
        self.s_cl = Es_cl.noun#пример
        self.animate = []
        self.gender = []
        self.number = [] 
        self.case1 = [] 
        self.reflection = [] 
        self.perfective = [] 
        self.transitive = [] 
        self.person = [] 
        self.tense = [] 
        self.voice = [] 
        self.degree = [] 
        self.static = []

# %%
def createProperties():
    properties = {}
    # noun
    curProp = PropertyPartSpeech()
    curProp.s_cl = Es_cl.noun
    curProp.animate = [Eanimate.animate, Eanimate.unanimate, Eanimate.animateAny]
    curProp.gender = [Egender.male, Egender.female, Egender.neuter, Egender.malefemale, Egender.maleorfemale, Egender.genderAny]
    curProp.number = [Enumber.single, Enumber.plural, Enumber.numberAny]
    curProp.case1 = [Ecase.nominative, Ecase.genitive, Ecase.dative, Ecase.accusative, Ecase.instrumental, Ecase.prepositional, Ecase.caseAny]
    curProp.ref1ection = [Ereflection.reflexive, Ereflection.unreflexive, Ereflection.reflexiveForm, Ereflection.reflectionAny]
    curProp.perfective = [Eperfective.perfective, Eperfective.unperfective, Eperfective.perfectiveAny]
    curProp.transitive = [Etransitive.transitive, Etransitive.untransitive, Etransitive.transitiveAny]
    curProp.person = [Eperson.first, Eperson.second, Eperson.third, Eperson.personAny]
    curProp.tense = [Etense.infinitive, Etense.present, Etense.past, Etense.future, Etense.imperative, Etense.tenseAny]
    curProp.voice = [Evoice.active, Evoice.passive, Evoice.voiceAny]
    curProp.degree = [Edegree.strong, Edegree.weak, Edegree.degreeAny]
    curProp.static = [False]
    properties[Es_cl.noun] = curProp
    # вставка personal pronoun(личные местоимения)
    # изменяемые характеристики: падеж
    #<од.><род><число><лицо>
    #  я, ты,  мы, вы, он, она, оно, они
    #(перебор animate, gender, number,case,person - потом сузить)
    i = 1
    curProp = PropertyPartSpeech()
    curProp.s_cl = Es_cl.personalpronoun
    curProp.animate = [Eanimate.animate, Eanimate.unanimate, Eanimate.animateAny]
    curProp.gender = [Egender.male, Egender.female, Egender.neuter, Egender.genderAny]
    curProp.number = [Enumber.single, Enumber.plural]
    curProp.case1 = [Ecase.nominative, Ecase.genitive, Ecase.dative, Ecase.accusative, Ecase.instrumental, Ecase.prepositional]
    curProp.ref1ection = [Ereflection.reflectionAny]
    curProp.perfective = [Eperfective.perfectiveAny]
    curProp.transitive = [Etransitive.transitiveAny]
    curProp.person = [Eperson.first, Eperson.second, Eperson.third]
    curProp.tense = [Etense.tenseAny]
    curProp.voice = [Evoice.voiceAny]
    curProp.degree = [Edegree.degreeAny]
    curProp.static = [False]
    properties[Es_cl.personalpronoun] = curProp
    #reflexive pronoun
    #изменяемые характеристики: падеж
    #<од.><род><число>
    curProp = PropertyPartSpeech()
    curProp.s_cl = Es_cl.reflexivepronoun
    curProp.animate = [Eanimate.animate, Eanimate.unanimate, Eanimate.animateAny]
    curProp.gender = [Egender.male, Egender.female, Egender.neuter, Egender.genderAny]
    curProp.number = [Enumber.single, Enumber.plural, Enumber.numberAny]
    curProp.case1 = [Ecase.nominative, Ecase.genitive, Ecase.dative, Ecase.accusative, Ecase.instrumental, Ecase.prepositional, Ecase.caseAny]
    curProp.ref1ection = [Ereflection.reflectionAny]
    curProp.perfective = [Eperfective.perfectiveAny]
    curProp.transitive = [Etransitive.transitiveAny]
    curProp.person = [Eperson.personAny]
    curProp.tense = [Etense.tenseAny]
    curProp.voice = [Evoice.voiceAny]
    curProp.degree = [Edegree.degreeAny]
    curProp.static = [False]
    properties[Es_cl.reflexivepronoun] = curProp
    # pronoun
    # ПЕРЕДЕЛАТЬ!!! (сильно сузить)
    # изменяемые характеристики: падеж
    #<од.><род><число>
    curProp = PropertyPartSpeech()
    curProp.s_cl = Es_cl.pronoun
    curProp.animate = [Eanimate.animate, Eanimate.unanimate, Eanimate.animateAny]
    curProp.gender = [Egender.male, Egender.female, Egender.neuter, Egender.malefemale, Egender.maleorfemale, Egender.genderAny]
    curProp.number = [Enumber.single, Enumber.plural, Enumber.numberAny]
    curProp.case1 = [Ecase.nominative, Ecase.genitive, Ecase.dative, Ecase.accusative, Ecase.instrumental, Ecase.prepositional, Ecase.caseAny]
    curProp.ref1ection = [Ereflection.reflectionAny]
    curProp.perfective = [Eperfective.perfectiveAny]
    curProp.transitive = [Etransitive.transitiveAny]
    curProp.person = [Eperson.first, Eperson.second, Eperson.third, Eperson.personAny]
    curProp.tense = [Etense.tenseAny]
    curProp.voice = [Evoice.voiceAny]
    curProp.degree = [Edegree.degreeAny]
    curProp.static = [True, False]
    properties[Es_cl.pronoun] = curProp
    #name
    # ПЕРЕДЕЛАТЬ!!! (сузить)
    # пока не выполняется(т.к. не выделяется) Пока нет в базе
    curProp = PropertyPartSpeech()
    curProp.s_cl = Es_cl.name
    curProp.animate = [Eanimate.animate, Eanimate.unanimate, Eanimate.animateAny]
    curProp.gender = [Egender.male, Egender.female, Egender.neuter, Egender.malefemale, Egender.maleorfemale, Egender.genderAny]
    curProp.number = [Enumber.single, Enumber.plural, Enumber.numberAny]
    curProp.case1 = [Ecase.nominative, Ecase.genitive, Ecase.dative, Ecase.accusative, Ecase.instrumental, Ecase.prepositional, Ecase.caseAny]
    curProp.ref1ection = [Ereflection.reflectionAny]
    curProp.perfective = [Eperfective.perfectiveAny]
    curProp.transitive = [Etransitive.transitiveAny]
    curProp.person = [Eperson.personAny]
    curProp.tense = [Etense.tenseAny]
    curProp.voice = [Evoice.voiceAny]
    curProp.degree = [Edegree.degreeAny]
    curProp.static = [False]
    properties[Es_cl.name] = curProp
    #adjective
    #од., род, число, падеж
    # ПЕРЕДЕЛАТЬ!!! (сузить)
    curProp = PropertyPartSpeech()
    curProp.s_cl = Es_cl.adjective
    curProp.animate = [Eanimate.animate, Eanimate.unanimate, Eanimate.animateAny]
    curProp.gender = [Egender.male, Egender.female, Egender.neuter, Egender.malefemale, Egender.maleorfemale, Egender.genderAny]
    curProp.number = [Enumber.single, Enumber.plural]
    curProp.case1 = [Ecase.nominative, Ecase.genitive, Ecase.dative, Ecase.accusative, Ecase.instrumental, Ecase.prepositional]
    curProp.ref1ection = [Ereflection.reflectionAny]
    curProp.perfective = [Eperfective.perfectiveAny]
    curProp.transitive = [Etransitive.transitiveAny]
    curProp.person = [Eperson.personAny]
    curProp.tense = [Etense.tenseAny]
    curProp.voice = [Evoice.voiceAny]
    curProp.degree = [Edegree.degreeAny]
    curProp.static = [False]
    properties[Es_cl.adjective] = curProp
    #possesiveadjective
    # ПЕРЕДЕЛАТЬ!!! (сузить)
    # од., род, число, падеж.
    curProp = PropertyPartSpeech()
    curProp.s_cl = Es_cl.possesiveadjective
    curProp.animate = [Eanimate.animate, Eanimate.unanimate, Eanimate.animateAny]
    curProp.gender = [Egender.male, Egender.female, Egender.neuter, Egender.malefemale, Egender.maleorfemale, Egender.genderAny]
    curProp.number = [Enumber.single, Enumber.plural, Enumber.numberAny]
    curProp.case1 = [Ecase.nominative, Ecase.genitive, Ecase.dative, Ecase.accusative, Ecase.instrumental, Ecase.prepositional, Ecase.caseAny]
    curProp.ref1ection = [Ereflection.reflectionAny]
    curProp.perfective = [Eperfective.perfectiveAny]
    curProp.transitive = [Etransitive.transitiveAny]
    curProp.person = [Eperson.personAny]
    curProp.tense = [Etense.tenseAny]
    curProp.voice = [Evoice.voiceAny]
    curProp.degree = [Edegree.degreeAny]
    curProp.static = [False]
    properties[Es_cl.possesiveadjective] = curProp
    #pronounadjective
    # ПЕРЕДЕЛАТЬ!!! (сузить)
    #од., род, число, падеж.
    curProp = PropertyPartSpeech()
    curProp.s_cl = Es_cl.pronounadjective
    curProp.animate = [Eanimate.animate, Eanimate.unanimate, Eanimate.animateAny]
    curProp.gender = [Egender.male, Egender.female, Egender.neuter, Egender.malefemale, Egender.maleorfemale, Egender.genderAny]
    curProp.number = [Enumber.single, Enumber.plural, Enumber.numberAny]
    curProp.case1 = [Ecase.nominative, Ecase.genitive, Ecase.dative, Ecase.accusative, Ecase.instrumental, Ecase.prepositional, Ecase.caseAny]
    curProp.ref1ection = [Ereflection.reflectionAny]
    curProp.perfective = [Eperfective.perfectiveAny]
    curProp.transitive = [Etransitive.transitiveAny]
    curProp.person = [Eperson.personAny]
    curProp.tense = [Etense.tenseAny]
    curProp.voice = [Evoice.voiceAny]
    curProp.degree = [Edegree.degreeAny]
    curProp.static = [False]
    properties[Es_cl.pronounadjective] = curProp
    #numberordinal
    # ПЕРЕДЕЛАТЬ!!! (сузить)
    #од., род, число, падеж.
    curProp = PropertyPartSpeech()
    curProp.s_cl = Es_cl.numberordinal
    curProp.animate = [Eanimate.animate, Eanimate.unanimate, Eanimate.animateAny]
    curProp.gender = [Egender.male, Egender.female, Egender.neuter, Egender.malefemale, Egender.maleorfemale, Egender.genderAny]
    curProp.number = [Enumber.single, Enumber.plural, Enumber.numberAny]
    curProp.case1 = [Ecase.nominative, Ecase.genitive, Ecase.dative, Ecase.accusative, Ecase.instrumental, Ecase.prepositional]
    curProp.ref1ection = [Ereflection.reflectionAny]
    curProp.perfective = [Eperfective.perfectiveAny]
    curProp.transitive = [Etransitive.transitiveAny]
    curProp.person = [Eperson.personAny]
    curProp.tense = [Etense.tenseAny]
    curProp.voice = [Evoice.voiceAny]
    curProp.degree = [Edegree.degreeAny]
    curProp.static = [False]
    properties[Es_cl.numberordinal] = curProp
    #'participle'
    #од, род, число, падеж,
    # ПЕРЕДЕЛАТЬ!!! (сузить)
    curProp = PropertyPartSpeech()
    curProp.s_cl = Es_cl.participle
    curProp.animate = [Eanimate.animate, Eanimate.unanimate, Eanimate.animateAny]
    curProp.gender = [Egender.male, Egender.female, Egender.neuter, Egender.genderAny]
    curProp.number = [Enumber.single, Enumber.plural]
    curProp.case1 = [Ecase.nominative, Ecase.genitive, Ecase.dative, Ecase.accusative, Ecase.instrumental, Ecase.prepositional]
    curProp.ref1ection = [Ereflection.unreflexive, Ereflection.reflexiveForm]
    curProp.perfective = [Eperfective.perfective, Eperfective.unperfective]
    curProp.transitive = [Etransitive.transitive, Etransitive.untransitive]
    curProp.person = [Eperson.personAny]
    curProp.tense = [Etense.present, Etense.past]
    curProp.voice = [Evoice.active, Evoice.passive]
    curProp.degree = [Edegree.strong, Edegree.weak, Edegree.degreeAny]
    curProp.static = [False]
    properties[Es_cl.participle] = curProp
    #'shortadjective'
    #для кратких форм - род, число
    curProp = PropertyPartSpeech()
    curProp.s_cl = Es_cl.shortadjective
    curProp.animate = [Eanimate.animate, Eanimate.unanimate, Eanimate.animateAny]
    curProp.gender = [Egender.male, Egender.female, Egender.neuter, Egender.malefemale, Egender.maleorfemale, Egender.genderAny]
    curProp.number = [Enumber.single, Enumber.plural, Enumber.numberAny]
    curProp.case1 = [Ecase.caseAny]
    curProp.ref1ection = [Ereflection.reflectionAny]
    curProp.perfective = [Eperfective.perfectiveAny]
    curProp.transitive = [Etransitive.transitiveAny]
    curProp.person = [Eperson.personAny]
    curProp.tense = [Etense.tenseAny]
    curProp.voice = [Evoice.voiceAny]
    curProp.degree = [Edegree.degreeAny]
    curProp.static = [False]
    properties[Es_cl.shortadjective] = curProp
    #'shortparticiple'
    #род и число.
    curProp = PropertyPartSpeech()
    curProp.s_cl = Es_cl.shortparticiple
    curProp.animate = [Eanimate.animate, Eanimate.unanimate, Eanimate.animateAny]
    curProp.gender = [Egender.male, Egender.female, Egender.neuter, Egender.genderAny]
    curProp.number = [Enumber.single, Enumber.plural]
    curProp.case1 = [Ecase.caseAny]
    curProp.ref1ection = [Ereflection.unreflexive, Ereflection.reflexiveForm]
    curProp.perfective = [Eperfective.perfective, Eperfective.unperfective]
    curProp.transitive = [Etransitive.transitive, Etransitive.untransitive, Etransitive.transitiveAny]
    curProp.person = [Eperson.personAny]
    curProp.tense = [Etense.present, Etense.past]
    curProp.voice = [Evoice.active, Evoice.passive]
    curProp.degree = [Edegree.strong, Edegree.weak, Edegree.degreeAny]
    curProp.static = [False]
    properties[Es_cl.shortparticiple] = curProp
    #'comparative'
    curProp = PropertyPartSpeech()
    curProp.s_cl = Es_cl.comparative
    curProp.animate = [Eanimate.animate, Eanimate.unanimate, Eanimate.animateAny]
    curProp.gender = [Egender.genderAny]
    curProp.number = [Enumber.numberAny]
    curProp.case1 = [Ecase.caseAny]
    curProp.ref1ection = [Ereflection.reflectionAny]
    curProp.perfective = [Eperfective.perfectiveAny]
    curProp.transitive = [Etransitive.transitiveAny]
    curProp.person = [Eperson.personAny]
    curProp.tense = [Etense.tenseAny]
    curProp.voice = [Evoice.voiceAny]
    curProp.degree = [Edegree.degreeAny]
    curProp.degree = [Edegree.strong, Edegree.weak, Edegree.degreeAny]
    curProp.static = [True, False]
    properties[Es_cl.comparative] = curProp
    #вставка глаголов ПЕРЕДЕЛАТЬ!!!!(сузить)
    #"verb"
    curProp = PropertyPartSpeech()
    curProp.s_cl = Es_cl.verb
    curProp.animate = [Eanimate.animateAny]
    curProp.gender = [Egender.male, Egender.female, Egender.neuter, Egender.malefemale, Egender.maleorfemale, Egender.genderAny]
    curProp.number = [Enumber.single, Enumber.plural, Enumber.numberAny]
    curProp.case1 = [Ecase.caseAny]
    curProp.ref1ection = [Ereflection.reflexive, Ereflection.unreflexive, Ereflection.reflexiveForm]
    curProp.perfective = [Eperfective.perfective, Eperfective.unperfective]
    curProp.transitive = [Etransitive.transitive, Etransitive.untransitive]
    curProp.person = [Eperson.first, Eperson.second, Eperson.third, Eperson.personAny]
    curProp.tense = [Etense.infinitive, Etense.present, Etense.past, Etense.future, Etense.imperative]
    curProp.voice = [Evoice.active, Evoice.passive, Evoice.voiceAny]
    curProp.degree = [Edegree.degreeAny]
    curProp.static = [False]
    properties[Es_cl.verb] = curProp
    #'unpersonalverb'   безличные глаголы
    # ПЕРЕДЕЛАТЬ!!! (сильно сузить)
    curProp = PropertyPartSpeech()
    curProp.s_cl = Es_cl.unpersonalverb
    curProp.animate = [Eanimate.animateAny]
    curProp.gender = [Egender.male, Egender.female, Egender.neuter, Egender.genderAny]
    curProp.number = [Enumber.single, Enumber.plural]
    curProp.case1 = [Ecase.caseAny]
    curProp.ref1ection = [Ereflection.reflexive, Ereflection.unreflexive, Ereflection.reflexiveForm, Ereflection.reflectionAny]
    curProp.perfective = [Eperfective.perfective, Eperfective.unperfective, Eperfective.perfectiveAny]
    curProp.transitive = [Etransitive.transitive, Etransitive.untransitive, Etransitive.transitiveAny]
    curProp.person = [Eperson.first, Eperson.second, Eperson.third, Eperson.personAny]
    curProp.tense = [Etense.infinitive, Etense.present, Etense.past, Etense.future, Etense.imperative, Etense.tenseAny]
    curProp.voice = [Evoice.active, Evoice.passive, Evoice.voiceAny]
    curProp.degree = [Edegree.strong, Edegree.weak, Edegree.degreeAny]
    curProp.static = [True, False]
    properties[Es_cl.unpersonalverb] = curProp
    #frequentativeverb (плохо выделяются анализатором)
    # ПЕРЕДЕЛАТЬ!!! (сильно сузить)
    curProp = PropertyPartSpeech()
    curProp.s_cl = Es_cl.frequentativeverb
    curProp.animate = [Eanimate.animateAny]
    curProp.gender = [Egender.genderAny]
    curProp.number = [Enumber.numberAny]
    curProp.case1 = [Ecase.caseAny]
    curProp.ref1ection = [Ereflection.reflexive, Ereflection.unreflexive, Ereflection.reflexiveForm, Ereflection.reflectionAny]
    curProp.perfective = [Eperfective.perfective, Eperfective.unperfective, Eperfective.perfectiveAny]
    curProp.transitive = [Etransitive.transitive, Etransitive.untransitive, Etransitive.transitiveAny]
    curProp.person = [Eperson.first, Eperson.second, Eperson.third, Eperson.personAny]
    curProp.tense = [Etense.infinitive, Etense.present, Etense.past, Etense.future, Etense.imperative, Etense.tenseAny]
    curProp.voice = [Evoice.active, Evoice.passive, Evoice.voiceAny]
    curProp.degree = [Edegree.strong, Edegree.weak, Edegree.degreeAny]
    curProp.static = [True, False]
    properties[Es_cl.frequentativeverb] = curProp
    #gerund
    curProp = PropertyPartSpeech()
    curProp.s_cl = Es_cl.gerund
    curProp.animate = [Eanimate.animate, Eanimate.unanimate, Eanimate.animateAny]
    curProp.gender = [Egender.genderAny]
    curProp.number = [Enumber.numberAny]
    curProp.case1 = [Ecase.caseAny]
    curProp.ref1ection = [Ereflection.reflexive, Ereflection.unreflexive, Ereflection.reflexiveForm, Ereflection.reflectionAny]
    curProp.perfective = [Eperfective.perfective, Eperfective.unperfective, Eperfective.perfectiveAny]
    curProp.transitive = [Etransitive.transitive, Etransitive.untransitive, Etransitive.transitiveAny]
    curProp.person = [Eperson.personAny]
    curProp.tense = [Etense.infinitive, Etense.present, Etense.past, Etense.future, Etense.imperative, Etense.tenseAny]
    curProp.voice = [Evoice.active, Evoice.passive, Evoice.voiceAny]
    curProp.degree = [Edegree.strong, Edegree.weak, Edegree.degreeAny]
    curProp.static = [True]
    properties[Es_cl.gerund] = curProp
    # numberone   числительное один
    #изменяемые характеристики: од., род, число, падеж
    curProp = PropertyPartSpeech()
    curProp.s_cl = Es_cl.numberone
    curProp.animate = [Eanimate.animate, Eanimate.unanimate, Eanimate.animateAny]
    curProp.gender = [Egender.male, Egender.female, Egender.neuter, Egender.malefemale, Egender.maleorfemale, Egender.genderAny]
    curProp.number = [Enumber.single, Enumber.plural, Enumber.numberAny]
    curProp.case1 = [Ecase.nominative, Ecase.genitive, Ecase.dative, Ecase.accusative, Ecase.instrumental, Ecase.prepositional, Ecase.caseAny]
    curProp.ref1ection = [Ereflection.reflectionAny]
    curProp.perfective = [Eperfective.perfectiveAny]
    curProp.transitive = [Etransitive.transitiveAny]
    curProp.person = [Eperson.personAny]
    curProp.tense = [Etense.tenseAny]
    curProp.voice = [Evoice.voiceAny]
    curProp.degree = [Edegree.strong, Edegree.weak, Edegree.degreeAny]
    curProp.static = [False]
    properties[Es_cl.numberone] = curProp
    #numbertwo 'два', 'оба', 'полтора'
    #изменяемые характеристики: од.,род, падеж
    curProp = PropertyPartSpeech()
    curProp.s_cl = Es_cl.numbertwo
    curProp.animate = [Eanimate.animate, Eanimate.unanimate, Eanimate.animateAny]
    curProp.gender = [Egender.male, Egender.female, Egender.neuter, Egender.malefemale, Egender.maleorfemale, Egender.genderAny]
    curProp.number = [Enumber.numberAny]
    curProp.case1 = [Ecase.nominative, Ecase.genitive, Ecase.dative, Ecase.accusative, Ecase.instrumental, Ecase.prepositional, Ecase.caseAny]
    curProp.ref1ection = [Ereflection.reflectionAny]
    curProp.perfective = [Eperfective.perfectiveAny]
    curProp.transitive = [Etransitive.transitiveAny]
    curProp.person = [Eperson.personAny]
    curProp.tense = [Etense.tenseAny]
    curProp.voice = [Evoice.voiceAny]
    curProp.degree = [Edegree.strong, Edegree.weak, Edegree.degreeAny]
    curProp.static = [False]
    properties[Es_cl.numbertwo] = curProp
    #numberthree
    #три, четыре, сколько, несколько, столько, много, немного  и собирательные!
    # од., падеж.
    curProp = PropertyPartSpeech()
    curProp.s_cl = Es_cl.numberthree
    curProp.animate = [Eanimate.animate, Eanimate.unanimate, Eanimate.animateAny]
    curProp.gender = [Egender.genderAny]
    curProp.number = [Enumber.numberAny]
    curProp.case1 = [Ecase.nominative, Ecase.genitive, Ecase.dative, Ecase.accusative, Ecase.instrumental, Ecase.prepositional, Ecase.caseAny]
    curProp.ref1ection = [Ereflection.reflectionAny]
    curProp.perfective = [Eperfective.perfectiveAny]
    curProp.transitive = [Etransitive.transitiveAny]
    curProp.person = [Eperson.personAny]
    curProp.tense = [Etense.tenseAny]
    curProp.voice = [Evoice.voiceAny]
    curProp.degree = [Edegree.strong, Edegree.weak, Edegree.degreeAny]
    curProp.static = [False]
    properties[Es_cl.numberthree] = curProp
    # number
    #количественные числительные
    #изменяемые характеристики: падеж
    curProp = PropertyPartSpeech()
    curProp.s_cl = Es_cl.number
    curProp.animate = [Eanimate.animateAny]
    curProp.gender = [Egender.genderAny]
    curProp.number = [Enumber.numberAny]
    curProp.case1 = [Ecase.nominative, Ecase.genitive, Ecase.dative, Ecase.accusative, Ecase.instrumental, Ecase.prepositional, Ecase.caseAny]
    curProp.ref1ection = [Ereflection.reflectionAny]
    curProp.perfective = [Eperfective.perfectiveAny]
    curProp.transitive = [Etransitive.transitiveAny]
    curProp.person = [Eperson.personAny]
    curProp.tense = [Etense.tenseAny]
    curProp.voice = [Evoice.voiceAny]
    curProp.degree = [Edegree.strong, Edegree.weak, Edegree.degreeAny]
    curProp.static = [False]
    properties[Es_cl.number] = curProp
    #numberbiform НЕ ПОНЯЛА, что это (полный перебор)
    #переборный образец
    # ПОКА НЕ ВЫПОЛНЯЛСЯ(в таблице morf_characters_of_word его нет)!!!
    curProp = PropertyPartSpeech()
    curProp.s_cl = Es_cl.numberbiform
    curProp.animate = [Eanimate.animate, Eanimate.unanimate, Eanimate.animateAny]
    curProp.gender = [Egender.male, Egender.female, Egender.neuter, Egender.malefemale, Egender.maleorfemale, Egender.genderAny]
    curProp.number = [Enumber.single, Enumber.plural, Enumber.numberAny]
    curProp.case1 = [Ecase.nominative, Ecase.genitive, Ecase.dative, Ecase.accusative, Ecase.instrumental, Ecase.prepositional, Ecase.caseAny]
    curProp.ref1ection = [Ereflection.reflexive, Ereflection.unreflexive, Ereflection.reflexiveForm, Ereflection.reflectionAny]
    curProp.perfective = [Eperfective.perfective, Eperfective.unperfective, Eperfective.perfectiveAny]
    curProp.transitive = [Etransitive.transitive, Etransitive.untransitive, Etransitive.transitiveAny]
    curProp.person = [Eperson.first, Eperson.second, Eperson.third, Eperson.personAny]
    curProp.tense = [Etense.infinitive, Etense.present, Etense.past, Etense.future, Etense.imperative, Etense.tenseAny]
    curProp.voice = [Evoice.active, Evoice.passive, Evoice.voiceAny]
    curProp.degree = [Edegree.strong, Edegree.weak, Edegree.degreeAny]
    curProp.static = [True, False]
    properties[Es_cl.numberbiform] = curProp
    #adverb
    curProp = PropertyPartSpeech()
    curProp.s_cl = Es_cl.adverb
    curProp.animate = [Eanimate.animateAny]
    curProp.gender = [Egender.genderAny]
    curProp.number = [Enumber.numberAny]
    curProp.case1 = [Ecase.caseAny]
    curProp.ref1ection = [Ereflection.reflectionAny]
    curProp.perfective = [Eperfective.perfectiveAny]
    curProp.transitive = [Etransitive.transitiveAny]
    curProp.person = [Eperson.personAny]
    curProp.tense = [Etense.tenseAny]
    curProp.voice = [Evoice.voiceAny]
    curProp.degree = [Edegree.degreeAny]
    curProp.static = [True]
    properties[Es_cl.adverb] = curProp
    #preposition(предлог)
    curProp = PropertyPartSpeech()
    curProp.s_cl = Es_cl.preposition
    curProp.animate = [Eanimate.animateAny]
    curProp.gender = [Egender.genderAny]
    curProp.number = [Enumber.numberAny]
    curProp.case1 = [Ecase.caseAny]
    curProp.ref1ection = [Ereflection.reflectionAny]
    curProp.perfective = [Eperfective.perfectiveAny]
    curProp.transitive = [Etransitive.transitiveAny]
    curProp.person = [Eperson.personAny]
    curProp.tense = [Etense.tenseAny]
    curProp.voice = [Evoice.voiceAny]
    curProp.degree = [Edegree.degreeAny]
    curProp.static = [True]
    properties[Es_cl.preposition] = curProp
    #conjunction союз
    curProp = PropertyPartSpeech()
    curProp.s_cl = Es_cl.conjunction
    curProp.animate = [Eanimate.animateAny]
    curProp.gender = [Egender.genderAny]
    curProp.number = [Enumber.numberAny]
    curProp.case1 = [Ecase.caseAny]
    curProp.ref1ection = [Ereflection.reflectionAny]
    curProp.perfective = [Eperfective.perfectiveAny]
    curProp.transitive = [Etransitive.transitiveAny]
    curProp.person = [Eperson.personAny]
    curProp.tense = [Etense.tenseAny]
    curProp.voice = [Evoice.voiceAny]
    curProp.degree = [Edegree.degreeAny]
    curProp.static = [True]
    properties[Es_cl.conjunction] = curProp
    #predicative категория состояния
    #сузить очень сильно!!!!!!!!!(полный перебор)
    #  ПОКА НЕ В БАЗЕ !!!!!!
    curProp = PropertyPartSpeech()
    curProp.s_cl = Es_cl.predicative
    curProp.animate = [Eanimate.animate, Eanimate.unanimate, Eanimate.animateAny]
    curProp.gender = [Egender.male, Egender.female, Egender.neuter, Egender.malefemale, Egender.maleorfemale, Egender.genderAny]
    curProp.number = [Enumber.single, Enumber.plural, Enumber.numberAny]
    curProp.case1 = [Ecase.nominative, Ecase.genitive, Ecase.dative, Ecase.accusative, Ecase.instrumental, Ecase.prepositional, Ecase.caseAny]
    curProp.ref1ection = [Ereflection.reflexive, Ereflection.unreflexive, Ereflection.reflexiveForm, Ereflection.reflectionAny]
    curProp.perfective = [Eperfective.perfective, Eperfective.unperfective, Eperfective.perfectiveAny]
    curProp.transitive = [Etransitive.transitive, Etransitive.untransitive, Etransitive.transitiveAny]
    curProp.person = [Eperson.first, Eperson.second, Eperson.third, Eperson.personAny]
    curProp.tense = [Etense.infinitive, Etense.present, Etense.past, Etense.future, Etense.imperative, Etense.tenseAny]
    curProp.voice = [Evoice.active, Evoice.passive, Evoice.voiceAny]
    curProp.degree = [Edegree.strong, Edegree.weak, Edegree.degreeAny]
    curProp.static = [True, False]
    properties[Es_cl.predicative] = curProp
    #particle (частица)
    curProp = PropertyPartSpeech()
    curProp.s_cl = Es_cl.particle
    curProp.animate = [Eanimate.animateAny]
    curProp.gender = [Egender.genderAny]
    curProp.number = [Enumber.numberAny]
    curProp.case1 = [Ecase.caseAny]
    curProp.ref1ection = [Ereflection.reflectionAny]
    curProp.perfective = [Eperfective.perfectiveAny]
    curProp.transitive = [Etransitive.transitiveAny]
    curProp.person = [Eperson.personAny]
    curProp.tense = [Etense.tenseAny]
    curProp.voice = [Evoice.voiceAny]
    curProp.degree = [Edegree.degreeAny]
    curProp.static = [True]
    properties[Es_cl.particle] = curProp
    #interjection (междометие)
    curProp = PropertyPartSpeech()
    curProp.s_cl = Es_cl.interjection
    curProp.animate = [Eanimate.animateAny]
    curProp.gender = [Egender.genderAny]
    curProp.number = [Enumber.numberAny]
    curProp.case1 = [Ecase.caseAny]
    curProp.ref1ection = [Ereflection.reflectionAny]
    curProp.perfective = [Eperfective.perfectiveAny]
    curProp.transitive = [Etransitive.transitiveAny]
    curProp.person = [Eperson.personAny]
    curProp.tense = [Etense.tenseAny]
    curProp.voice = [Evoice.voiceAny]
    curProp.degree = [Edegree.degreeAny]
    curProp.static = [True]
    properties[Es_cl.interjection] = curProp
    #acronym
    # нет в базе
    curProp = PropertyPartSpeech()
    curProp.s_cl = Es_cl.acronym
    curProp.animate = [Eanimate.animate, Eanimate.unanimate, Eanimate.animateAny]
    curProp.gender = [Egender.male, Egender.female, Egender.neuter, Egender.malefemale, Egender.maleorfemale, Egender.genderAny]
    curProp.number = [Enumber.single, Enumber.plural, Enumber.numberAny]
    curProp.case1 = [Ecase.nominative, Ecase.genitive, Ecase.dative, Ecase.accusative, Ecase.instrumental, Ecase.prepositional, Ecase.caseAny]
    curProp.ref1ection = [Ereflection.reflexive, Ereflection.unreflexive, Ereflection.reflexiveForm, Ereflection.reflectionAny]
    curProp.perfective = [Eperfective.perfective, Eperfective.unperfective, Eperfective.perfectiveAny]
    curProp.transitive = [Etransitive.transitive, Etransitive.untransitive, Etransitive.transitiveAny]
    curProp.person = [Eperson.first, Eperson.second, Eperson.third, Eperson.personAny]
    curProp.tense = [Etense.infinitive, Etense.present, Etense.past, Etense.future, Etense.imperative, Etense.tenseAny]
    curProp.voice = [Evoice.active, Evoice.passive, Evoice.voiceAny]
    curProp.degree = [Edegree.strong, Edegree.weak, Edegree.degreeAny]
    curProp.static = [True, False]
    properties[Es_cl.acronym] = curProp
    curProp = PropertyPartSpeech()
    properties['S_clAny'] = curProp
    return properties

# %%
res = createProperties()

# %%
for i in res:
    print(i, res[i])
# Out:
# Es_cl.numberone <__main__.PropertyPartSpeech object at 0x7fe1267bda58>
# Es_cl.noun <__main__.PropertyPartSpeech object at 0x7fe1342dce80>
# Es_cl.participle <__main__.PropertyPartSpeech object at 0x7fe1342dc198>
# Es_cl.reflexivepronoun <__main__.PropertyPartSpeech object at 0x7fe1342dc128>
# Es_cl.adjective <__main__.PropertyPartSpeech object at 0x7fe1342dcda0>
# Es_cl.comparative <__main__.PropertyPartSpeech object at 0x7fe1267bd128>
# Es_cl.shortparticiple <__main__.PropertyPartSpeech object at 0x7fe1267bdb38>
# Es_cl.acronym <__main__.PropertyPartSpeech object at 0x7fe1267bd860>
# Es_cl.personalpronoun <__main__.PropertyPartSpeech object at 0x7fe1342dca90>
# Es_cl.number <__main__.PropertyPartSpeech object at 0x7fe1267bd6d8>
# Es_cl.numberordinal <__main__.PropertyPartSpeech object at 0x7fe1342dc2e8>
# Es_cl.adverb <__main__.PropertyPartSpeech object at 0x7fe1267bd8d0>
# Es_cl.numberbiform <__main__.PropertyPartSpeech object at 0x7fe1267bdac8>
# ...

# %%
# noun
curProp = PropertyPartSpeech()
curProp.s_cl = Es_cl.noun
curProp.animate = [Eanimate.animate, Eanimate.unanimate, Eanimate.animateAny]
curProp.gender = [Egender.male, Egender.female, Egender.neuter, Egender.malefemale, Egender.maleorfemale, Egender.genderAny]
curProp.number = [Enumber.single, Enumber.plural, Enumber.numberAny]
curProp.case1 = [Ecase.nominative, Ecase.genitive, Ecase.dative, Ecase.accusative, Ecase.instrumental, Ecase.prepositional, Ecase.caseAny]
curProp.ref1ection = [Ereflection.reflexive, Ereflection.unreflexive, Ereflection.reflexiveForm, Ereflection.reflectionAny]
curProp.perfective = [Eperfective.perfective, Eperfective.unperfective, Eperfective.perfectiveAny]
curProp.transitive = [Etransitive.transitive, Etransitive.untransitive, Etransitive.transitiveAny]
curProp.person = [Eperson.first, Eperson.second, Eperson.third, Eperson.personAny]
curProp.tense = [Etense.infinitive, Etense.present, Etense.past, Etense.future, Etense.imperative, Etense.tenseAny]
curProp.voice = [Evoice.active, Evoice.passive, Evoice.voiceAny]
curProp.degree = [Edegree.strong, Edegree.weak, Edegree.degreeAny]
curProp.static = [False]
properties[Es_cl.noun] = curProp

# %%
# вставка personal pronoun(личные местоимения)
# изменяемые характеристики: падеж
#<од.><род><число><лицо>
#  я, ты,  мы, вы, он, она, оно, они
#(перебор animate, gender, number,case,person - потом сузить)
i = 1
curProp = PropertyPartSpeech()
curProp.s_cl = Es_cl.personalpronoun
curProp.animate = [Eanimate.animate, Eanimate.unanimate, Eanimate.animateAny]
curProp.gender = [Egender.male, Egender.female, Egender.neuter, Egender.genderAny]
curProp.number = [Enumber.single, Enumber.plural]
curProp.case1 = [Ecase.nominative, Ecase.genitive, Ecase.dative, Ecase.accusative, Ecase.instrumental, Ecase.prepositional]
curProp.ref1ection = [Ereflection.reflectionAny]
curProp.perfective = [Eperfective.perfectiveAny]
curProp.transitive = [Etransitive.transitiveAny]
curProp.person = [Eperson.first, Eperson.second, Eperson.third]
curProp.tense = [Etense.tenseAny]
curProp.voice = [Evoice.voiceAny]
curProp.degree = [Edegree.degreeAny]
curProp.static = [False]
properties[Es_cl.personalpronoun] = curProp

# %%
#reflexive pronoun
#изменяемые характеристики: падеж
#<од.><род><число>
curProp = PropertyPartSpeech()
curProp = Es_cl.reflexivepronoun
curProp.animate = [Eanimate.animate, Eanimate.unanimate, Eanimate.animateAny]
curProp.gender = [Egender.male, Egender.female, Egender.neuter, Egender.genderAny]
curProp.number = [Enumber.single, Enumber.plural, Enumber.numberAny]
curProp.case1 = [Ecase.nominative, Ecase.genitive, Ecase.dative, Ecase.accusative, Ecase.instrumental, Ecase.prepositional, Ecase.caseAny]
curProp.ref1ection = [Ereflection.reflectionAny]
curProp.perfective = [Eperfective.perfectiveAny]
curProp.transitive = [Etransitive.transitiveAny]
curProp.person = [Eperson.personAny]
curProp.tense = [Etense.tenseAny]
curProp.voice = [Evoice.voiceAny]
curProp.degree = [Edegree.degreeAny]
curProp.static = [False]
properties[Es_cl.reflexivepronoun] = curProp

# %%
# pronoun
# ПЕРЕДЕЛАТЬ!!! (сильно сузить)
# изменяемые характеристики: падеж
#<од.><род><число>
curProp = PropertyPartSpeech()
curProp.s_cl = Es_cl.pronoun
curProp.animate = [Eanimate.animate, Eanimate.unanimate, Eanimate.animateAny]
curProp.gender = [Egender.male, Egender.female, Egender.neuter, Egender.malefemale, Egender.maleorfemale, Egender.genderAny]
curProp.number = [Enumber.single, Enumber.plural, Enumber.numberAny]
curProp.case1 = [Ecase.nominative, Ecase.genitive, Ecase.dative, Ecase.accusative, Ecase.instrumental, Ecase.prepositional, Ecase.caseAny]
curProp.ref1ection = [Ereflection.reflectionAny]
curProp.perfective = [Eperfective.perfectiveAny]
curProp.transitive = [Etransitive.transitiveAny]
curProp.person = [Eperson.first, Eperson.second, Eperson.third, Eperson.personAny]
curProp.tense = [Etense.tenseAny]
curProp.voice = [Evoice.voiceAny]
curProp.degree = [Edegree.degreeAny]
curProp.static = [True, False]
properties[Es_cl.pronoun] = curProp

# %%
#следующее не выполнять!!!

# %%
#name
# ПЕРЕДЕЛАТЬ!!! (сузить)
# пока не выполняется(т.к. не выделяется)
curProp = PropertyPartSpeech()
curProp.s_cl = Es_cl.name
curProp.animate = [Eanimate.animate, Eanimate.unanimate, Eanimate.animateAny]
curProp.gender = [Egender.male, Egender.female, Egender.neuter, Egender.malefemale, Egender.maleorfemale, Egender.genderAny]
curProp.number = [Enumber.single, Enumber.plural, Enumber.numberAny]
curProp.case1 = [Ecase.nominative, Ecase.genitive, Ecase.dative, Ecase.accusative, Ecase.instrumental, Ecase.prepositional, Ecase.caseAny]
curProp.ref1ection = [Ereflection.reflectionAny]
curProp.perfective = [Eperfective.perfectiveAny]
curProp.transitive = [Etransitive.transitiveAny]
curProp.person = [Eperson.personAny]
curProp.tense = [Etense.tenseAny]
curProp.voice = [Evoice.voiceAny]
curProp.degree = [Edegree.degreeAny]
curProp.static = [False]
properties[Es_cl.name] = curProp

# %%
#adjective
#од., род, число, падеж
# ПЕРЕДЕЛАТЬ!!! (сузить)
curProp = PropertyPartSpeech()
curProp.s_cl = Es_cl.adjective
curProp.animate = [Eanimate.animate, Eanimate.unanimate, Eanimate.animateAny]
curProp.gender = [Egender.male, Egender.female, Egender.neuter, Egender.malefemale, Egender.maleorfemale, Egender.genderAny]
curProp.number = [Enumber.single, Enumber.plural]
curProp.case1 = [Ecase.nominative, Ecase.genitive, Ecase.dative, Ecase.accusative, Ecase.instrumental, Ecase.prepositional]
curProp.ref1ection = [Ereflection.reflectionAny]
curProp.perfective = [Eperfective.perfectiveAny]
curProp.transitive = [Etransitive.transitiveAny]
curProp.person = [Eperson.personAny]
curProp.tense = [Etense.tenseAny]
curProp.voice = [Evoice.voiceAny]
curProp.degree = [Edegree.degreeAny]
curProp.static = [False]
properties[Es_cl.adjective] = curProp

# %%
#possesiveadjective
# ПЕРЕДЕЛАТЬ!!! (сузить)
# од., род, число, падеж.
curProp = PropertyPartSpeech()
curProp.s_cl = Es_cl.possesiveadjective
curProp.animate = [Eanimate.animate, Eanimate.unanimate, Eanimate.animateAny]
curProp.gender = [Egender.male, Egender.female, Egender.neuter, Egender.malefemale, Egender.maleorfemale, Egender.genderAny]
curProp.number = [Enumber.single, Enumber.plural, Enumber.numberAny]
curProp.case1 = [Ecase.nominative, Ecase.genitive, Ecase.dative, Ecase.accusative, Ecase.instrumental, Ecase.prepositional, Ecase.caseAny]
curProp.ref1ection = [Ereflection.reflectionAny]
curProp.perfective = [Eperfective.perfectiveAny]
curProp.transitive = [Etransitive.transitiveAny]
curProp.person = [Eperson.personAny]
curProp.tense = [Etense.tenseAny]
curProp.voice = [Evoice.voiceAny]
curProp.degree = [Edegree.degreeAny]
curProp.static = [False]
properties[Es_cl.possesiveadjective] = curProp

# %%
#pronounadjective
# ПЕРЕДЕЛАТЬ!!! (сузить)
#од., род, число, падеж.
curProp = PropertyPartSpeech()
curProp.s_cl = Es_cl.pronounadjective
curProp.animate = [Eanimate.animate, Eanimate.unanimate, Eanimate.animateAny]
curProp.gender = [Egender.male, Egender.female, Egender.neuter, Egender.malefemale, Egender.maleorfemale, Egender.genderAny]
curProp.number = [Enumber.single, Enumber.plural, Enumber.numberAny]
curProp.case1 = [Ecase.nominative, Ecase.genitive, Ecase.dative, Ecase.accusative, Ecase.instrumental, Ecase.prepositional, Ecase.caseAny]
curProp.ref1ection = [Ereflection.reflectionAny]
curProp.perfective = [Eperfective.perfectiveAny]
curProp.transitive = [Etransitive.transitiveAny]
curProp.person = [Eperson.personAny]
curProp.tense = [Etense.tenseAny]
curProp.voice = [Evoice.voiceAny]
curProp.degree = [Edegree.degreeAny]
curProp.static = [False]
properties[Es_cl.pronounadjective] = curProp

# %%
#numberordinal
# ПЕРЕДЕЛАТЬ!!! (сузить)
#од., род, число, падеж.
curProp = PropertyPartSpeech()
curProp.s_cl = Es_cl.numberordinal
curProp.animate = [Eanimate.animate, Eanimate.unanimate, Eanimate.animateAny]
curProp.gender = [Egender.male, Egender.female, Egender.neuter, Egender.malefemale, Egender.maleorfemale, Egender.genderAny]
curProp.number = [Enumber.single, Enumber.plural, Enumber.numberAny]
curProp.case1 = [Ecase.nominative, Ecase.genitive, Ecase.dative, Ecase.accusative, Ecase.instrumental, Ecase.prepositional]
curProp.ref1ection = [Ereflection.reflectionAny]
curProp.perfective = [Eperfective.perfectiveAny]
curProp.transitive = [Etransitive.transitiveAny]
curProp.person = [Eperson.personAny]
curProp.tense = [Etense.tenseAny]
curProp.voice = [Evoice.voiceAny]
curProp.degree = [Edegree.degreeAny]
curProp.static = [False]
properties[Es_cl.numberordinal] = curProp

# %%
#'participle'
#од, род, число, падеж,
# ПЕРЕДЕЛАТЬ!!! (сузить)
curProp = PropertyPartSpeech()
curProp.s_cl = Es_cl.participle
curProp.animate = [Eanimate.animate, Eanimate.unanimate, Eanimate.animateAny]
curProp.gender = [Egender.male, Egender.female, Egender.neuter, Egender.genderAny]
curProp.number = [Enumber.single, Enumber.plural]
curProp.case1 = [Ecase.nominative, Ecase.genitive, Ecase.dative, Ecase.accusative, Ecase.instrumental, Ecase.prepositional]
curProp.ref1ection = [Ereflection.unreflexive, Ereflection.reflexiveForm]
curProp.perfective = [Eperfective.perfective, Eperfective.unperfective]
curProp.transitive = [Etransitive.transitive, Etransitive.untransitive]
curProp.person = [Eperson.personAny]
curProp.tense = [Etense.present, Etense.past]
curProp.voice = [Evoice.active, Evoice.passive]
curProp.degree = [Edegree.strong, Edegree.weak, Edegree.degreeAny]
curProp.static = [False]
properties[Es_cl.participle] = curProp

# %%
#'shortadjective'
#для кратких форм - род, число
curProp = PropertyPartSpeech()
curProp.s_cl = Es_cl.shortadjective
curProp.animate = [Eanimate.animate, Eanimate.unanimate, Eanimate.animateAny]
curProp.gender = [Egender.male, Egender.female, Egender.neuter, Egender.malefemale, Egender.maleorfemale, Egender.genderAny]
curProp.number = [Enumber.single, Enumber.plural, Enumber.numberAny]
curProp.case1 = [Ecase.caseAny]
curProp.ref1ection = [Ereflection.reflectionAny]
curProp.perfective = [Eperfective.perfectiveAny]
curProp.transitive = [Etransitive.transitiveAny]
curProp.person = [Eperson.personAny]
curProp.tense = [Etense.tenseAny]
curProp.voice = [Evoice.voiceAny]
curProp.degree = [Edegree.degreeAny]
curProp.static = [False]
properties[Es_cl.possesiveadjective] = curProp

# %%
#'shortparticiple'
#род и число.
curProp = PropertyPartSpeech()
curProp.s_cl = Es_cl.shortparticiple
curProp.animate = [Eanimate.animate, Eanimate.unanimate, Eanimate.animateAny]
curProp.gender = [Egender.male, Egender.female, Egender.neuter, Egender.genderAny]
curProp.number = [Enumber.single, Enumber.plural]
curProp.case1 = [Ecase.caseAny]
curProp.ref1ection = [Ereflection.unreflexive, Ereflection.reflexiveForm]
curProp.perfective = [Eperfective.perfective, Eperfective.unperfective]
curProp.transitive = [Etransitive.transitive, Etransitive.untransitive, Etransitive.transitiveAny]
curProp.person = [Eperson.personAny]
curProp.tense = [Etense.present, Etense.past]
curProp.voice = [Evoice.active, Evoice.passive]
curProp.degree = [Edegree.strong, Edegree.weak, Edegree.degreeAny]
curProp.static = [False]
properties[Es_cl.shortparticiple] = curProp

# %%
#'comparative'
curProp = PropertyPartSpeech()
curProp.s_cl = Es_cl.comparative
curProp.animate = [Eanimate.animate, Eanimate.unanimate, Eanimate.animateAny]
curProp.gender = [Egender.genderAny]
curProp.number = [Enumber.numberAny]
curProp.case1 = [Ecase.caseAny]
curProp.ref1ection = [Ereflection.reflectionAny]
curProp.perfective = [Eperfective.perfectiveAny]
curProp.transitive = [Etransitive.transitiveAny]
curProp.person = [Eperson.personAny]
curProp.tense = [Etense.tenseAny]
curProp.voice = [Evoice.voiceAny]
curProp.degree = [Edegree.degreeAny]
curProp.degree = [Edegree.strong, Edegree.weak, Edegree.degreeAny]
curProp.static = [True, False]
properties[Es_cl.comparative] = curProp

# %%
#вставка глаголов ПЕРЕДЕЛАТЬ!!!!(сузить)
#"verb"
curProp = PropertyPartSpeech()
curProp.s_cl = Es_cl.verb
curProp.animate = [Eanimate.animateAny]
curProp.gender = [Egender.male, Egender.female, Egender.neuter, Egender.malefemale, Egender.maleorfemale, Egender.genderAny]
curProp.number = [Enumber.single, Enumber.plural, Enumber.numberAny]
curProp.case1 = [Ecase.caseAny]
curProp.ref1ection = [Ereflection.reflexive, Ereflection.unreflexive, Ereflection.reflexiveForm]
curProp.perfective = [Eperfective.perfective, Eperfective.unperfective]
curProp.transitive = [Etransitive.transitive, Etransitive.untransitive]
curProp.person = [Eperson.first, Eperson.second, Eperson.third, Eperson.personAny]
curProp.tense = [Etense.infinitive, Etense.present, Etense.past, Etense.future, Etense.imperative]
curProp.voice = [Evoice.active, Evoice.passive, Evoice.voiceAny]
curProp.degree = [Edegree.degreeAny]
curProp.static = [False]
properties[Es_cl.verb] = curProp

# %%
#'unpersonalverb'   безличные глаголы
# ПЕРЕДЕЛАТЬ!!! (сильно сузить)
curProp = PropertyPartSpeech()
curProp.s_cl = Es_cl.unpersonalverb
curProp.animate = [Eanimate.animateAny]
curProp.gender = [Egender.male, Egender.female, Egender.neuter, Egender.genderAny]
curProp.number = [Enumber.single, Enumber.plural]
curProp.case1 = [Ecase.caseAny]
curProp.ref1ection = [Ereflection.reflexive, Ereflection.unreflexive, Ereflection.reflexiveForm, Ereflection.reflectionAny]
curProp.perfective = [Eperfective.perfective, Eperfective.unperfective, Eperfective.perfectiveAny]
curProp.transitive = [Etransitive.transitive, Etransitive.untransitive, Etransitive.transitiveAny]
curProp.person = [Eperson.first, Eperson.second, Eperson.third, Eperson.personAny]
curProp.tense = [Etense.infinitive, Etense.present, Etense.past, Etense.future, Etense.imperative, Etense.tenseAny]
curProp.voice = [Evoice.active, Evoice.passive, Evoice.voiceAny]
curProp.degree = [Edegree.strong, Edegree.weak, Edegree.degreeAny]
curProp.static = [True, False]
properties[Es_cl.unpersonalverb] = curProp

# %%
#frequentativeverb (плохо выделяются анализатором)
# ПЕРЕДЕЛАТЬ!!! (сильно сузить)
curProp = PropertyPartSpeech()
curProp.s_cl = Es_cl.frequentativeverb
curProp.animate = [Eanimate.animateAny]
curProp.gender = [Egender.genderAny]
curProp.number = [Enumber.numberAny]
curProp.case1 = [Ecase.caseAny]
curProp.ref1ection = [Ereflection.reflexive, Ereflection.unreflexive, Ereflection.reflexiveForm, Ereflection.reflectionAny]
curProp.perfective = [Eperfective.perfective, Eperfective.unperfective, Eperfective.perfectiveAny]
curProp.transitive = [Etransitive.transitive, Etransitive.untransitive, Etransitive.transitiveAny]
curProp.person = [Eperson.first, Eperson.second, Eperson.third, Eperson.personAny]
curProp.tense = [Etense.infinitive, Etense.present, Etense.past, Etense.future, Etense.imperative, Etense.tenseAny]
curProp.voice = [Evoice.active, Evoice.passive, Evoice.voiceAny]
curProp.degree = [Edegree.strong, Edegree.weak, Edegree.degreeAny]
curProp.static = [True, False]
properties[Es_cl.frequentativeverb] = curProp

# %%
#gerund
curProp = PropertyPartSpeech()
curProp.s_cl = Es_cl.gerund
curProp.animate = [Eanimate.animate, Eanimate.unanimate, Eanimate.animateAny]
curProp.gender = [Egender.genderAny]
curProp.number = [Enumber.numberAny]
curProp.case1 = [Ecase.caseAny]
curProp.ref1ection = [Ereflection.reflexive, Ereflection.unreflexive, Ereflection.reflexiveForm, Ereflection.reflectionAny]
curProp.perfective = [Eperfective.perfective, Eperfective.unperfective, Eperfective.perfectiveAny]
curProp.transitive = [Etransitive.transitive, Etransitive.untransitive, Etransitive.transitiveAny]
curProp.person = [Eperson.personAny]
curProp.tense = [Etense.infinitive, Etense.present, Etense.past, Etense.future, Etense.imperative, Etense.tenseAny]
curProp.voice = [Evoice.active, Evoice.passive, Evoice.voiceAny]
curProp.degree = [Edegree.strong, Edegree.weak, Edegree.degreeAny]
curProp.static = [True]
properties[Es_cl.gerund] = curProp

# %%
# numberone   числительное один
#изменяемые характеристики: од., род, число, падеж
curProp = PropertyPartSpeech()
curProp.s_cl = Es_cl.numberone
curProp.animate = [Eanimate.animate, Eanimate.unanimate, Eanimate.animateAny]
curProp.gender = [Egender.male, Egender.female, Egender.neuter, Egender.malefemale, Egender.maleorfemale, Egender.genderAny]
curProp.number = [Enumber.single, Enumber.plural, Enumber.numberAny]
curProp.case1 = [Ecase.nominative, Ecase.genitive, Ecase.dative, Ecase.accusative, Ecase.instrumental, Ecase.prepositional, Ecase.caseAny]
curProp.ref1ection = [Ereflection.reflectionAny]
curProp.perfective = [Eperfective.perfectiveAny]
curProp.transitive = [Etransitive.transitiveAny]
curProp.person = [Eperson.personAny]
curProp.tense = [Etense.tenseAny]
curProp.voice = [Evoice.voiceAny]
curProp.degree = [Edegree.strong, Edegree.weak, Edegree.degreeAny]
curProp.static = [False]
properties[Es_cl.numberone] = curProp

# %%
#numbertwo 'два', 'оба', 'полтора'
#изменяемые характеристики: од.,род, падеж
curProp = PropertyPartSpeech()
curProp.s_cl = Es_cl.numbertwo
curProp.animate = [Eanimate.animate, Eanimate.unanimate, Eanimate.animateAny]
curProp.gender = [Egender.male, Egender.female, Egender.neuter, Egender.malefemale, Egender.maleorfemale, Egender.genderAny]
curProp.number = [Enumber.numberAny]
curProp.case1 = [Ecase.nominative, Ecase.genitive, Ecase.dative, Ecase.accusative, Ecase.instrumental, Ecase.prepositional, Ecase.caseAny]
curProp.ref1ection = [Ereflection.reflectionAny]
curProp.perfective = [Eperfective.perfectiveAny]
curProp.transitive = [Etransitive.transitiveAny]
curProp.person = [Eperson.personAny]
curProp.tense = [Etense.tenseAny]
curProp.voice = [Evoice.voiceAny]
curProp.degree = [Edegree.strong, Edegree.weak, Edegree.degreeAny]
curProp.static = [False]
properties[Es_cl.numbertwo] = curProp

# %%
#numberthree
#три, четыре, сколько, несколько, столько, много, немного  и собирательные!
# од., падеж.
curProp = PropertyPartSpeech()
curProp.s_cl = Es_cl.numberthree
curProp.animate = [Eanimate.animate, Eanimate.unanimate, Eanimate.animateAny]
curProp.gender = [Egender.genderAny]
curProp.number = [Enumber.numberAny]
curProp.case1 = [Ecase.nominative, Ecase.genitive, Ecase.dative, Ecase.accusative, Ecase.instrumental, Ecase.prepositional, Ecase.caseAny]
curProp.ref1ection = [Ereflection.reflectionAny]
curProp.perfective = [Eperfective.perfectiveAny]
curProp.transitive = [Etransitive.transitiveAny]
curProp.person = [Eperson.personAny]
curProp.tense = [Etense.tenseAny]
curProp.voice = [Evoice.voiceAny]
curProp.degree = [Edegree.strong, Edegree.weak, Edegree.degreeAny]
curProp.static = [False]
properties[Es_cl.numberthree] = curProp

# %%
# number
#количественные числительные
#изменяемые характеристики: падеж
curProp = PropertyPartSpeech()
curProp.s_cl = Es_cl.number
curProp.animate = [Eanimate.animateAny]
curProp.gender = [Egender.genderAny]
curProp.number = [Enumber.numberAny]
curProp.case1 = [Ecase.nominative, Ecase.genitive, Ecase.dative, Ecase.accusative, Ecase.instrumental, Ecase.prepositional, Ecase.caseAny]
curProp.ref1ection = [Ereflection.reflectionAny]
curProp.perfective = [Eperfective.perfectiveAny]
curProp.transitive = [Etransitive.transitiveAny]
curProp.person = [Eperson.personAny]
curProp.tense = [Etense.tenseAny]
curProp.voice = [Evoice.voiceAny]
curProp.degree = [Edegree.strong, Edegree.weak, Edegree.degreeAny]
curProp.static = [False]
properties[Es_cl.number] = curProp

# %%
#следующее не выполнять!

# %%
#numberbiform НЕ ПОНЯЛА, что это (полный перебор)
#переборный образец
# ПОКА НЕ ВЫПОЛНЯЛСЯ(в таблице morf_characters_of_word его нет)!!!
curProp = PropertyPartSpeech()
curProp.s_cl = Es_cl.numberbiform
curProp.animate = [Eanimate.animate, Eanimate.unanimate, Eanimate.animateAny]
curProp.gender = [Egender.male, Egender.female, Egender.neuter, Egender.malefemale, Egender.maleorfemale, Egender.genderAny]
curProp.number = [Enumber.single, Enumber.plural, Enumber.numberAny]
curProp.case1 = [Ecase.nominative, Ecase.genitive, Ecase.dative, Ecase.accusative, Ecase.instrumental, Ecase.prepositional, Ecase.caseAny]
curProp.ref1ection = [Ereflection.reflexive, Ereflection.unreflexive, Ereflection.reflexiveForm, Ereflection.reflectionAny]
curProp.perfective = [Eperfective.perfective, Eperfective.unperfective, Eperfective.perfectiveAny]
curProp.transitive = [Etransitive.transitive, Etransitive.untransitive, Etransitive.transitiveAny]
curProp.person = [Eperson.first, Eperson.second, Eperson.third, Eperson.personAny]
curProp.tense = [Etense.infinitive, Etense.present, Etense.past, Etense.future, Etense.imperative, Etense.tenseAny]
curProp.voice = [Evoice.active, Evoice.passive, Evoice.voiceAny]
curProp.degree = [Edegree.strong, Edegree.weak, Edegree.degreeAny]
curProp.static = [True, False]
properties[Es_cl.numberbiform] = curProp

# %%
#adverb
curProp = PropertyPartSpeech()
curProp.s_cl = Es_cl.adverb
curProp.animate = [Eanimate.animateAny]
curProp.gender = [Egender.genderAny]
curProp.number = [Enumber.numberAny]
curProp.case1 = [Ecase.caseAny]
curProp.ref1ection = [Ereflection.reflectionAny]
curProp.perfective = [Eperfective.perfectiveAny]
curProp.transitive = [Etransitive.transitiveAny]
curProp.person = [Eperson.personAny]
curProp.tense = [Etense.tenseAny]
curProp.voice = [Evoice.voiceAny]
curProp.degree = [Edegree.degreeAny]
curProp.static = [True]
properties[Es_cl.adverb] = curProp

# %%
#preposition(предлог)
curProp = PropertyPartSpeech()
curProp.s_cl = Es_cl.preposition
curProp.animate = [Eanimate.animateAny]
curProp.gender = [Egender.genderAny]
curProp.number = [Enumber.numberAny]
curProp.case1 = [Ecase.caseAny]
curProp.ref1ection = [Ereflection.reflectionAny]
curProp.perfective = [Eperfective.perfectiveAny]
curProp.transitive = [Etransitive.transitiveAny]
curProp.person = [Eperson.personAny]
curProp.tense = [Etense.tenseAny]
curProp.voice = [Evoice.voiceAny]
curProp.degree = [Edegree.degreeAny]
curProp.static = [True]
properties[Es_cl.preposition] = curProp

# %%
#conjunction союз
curProp = PropertyPartSpeech()
curProp.s_cl = Es_cl.conjunction
curProp.animate = [Eanimate.animateAny]
curProp.gender = [Egender.genderAny]
curProp.number = [Enumber.numberAny]
curProp.case1 = [Ecase.caseAny]
curProp.ref1ection = [Ereflection.reflectionAny]
curProp.perfective = [Eperfective.perfectiveAny]
curProp.transitive = [Etransitive.transitiveAny]
curProp.person = [Eperson.personAny]
curProp.tense = [Etense.tenseAny]
curProp.voice = [Evoice.voiceAny]
curProp.degree = [Edegree.degreeAny]
curProp.static = [True]
properties[Es_cl.conjunction] = curProp

# %%
# следующее не выполнять

# %%
#predicative категория состояния
#сузить очень сильно!!!!!!!!!(полный перебор)
#  ПОКА НЕ В БАЗЕ !!!!!!
curProp = PropertyPartSpeech()
curProp.s_cl = Es_cl.predicative
curProp.animate = [Eanimate.animate, Eanimate.unanimate, Eanimate.animateAny]
curProp.gender = [Egender.male, Egender.female, Egender.neuter, Egender.malefemale, Egender.maleorfemale, Egender.genderAny]
curProp.number = [Enumber.single, Enumber.plural, Enumber.numberAny]
curProp.case1 = [Ecase.nominative, Ecase.genitive, Ecase.dative, Ecase.accusative, Ecase.instrumental, Ecase.prepositional, Ecase.caseAny]
curProp.ref1ection = [Ereflection.reflexive, Ereflection.unreflexive, Ereflection.reflexiveForm, Ereflection.reflectionAny]
curProp.perfective = [Eperfective.perfective, Eperfective.unperfective, Eperfective.perfectiveAny]
curProp.transitive = [Etransitive.transitive, Etransitive.untransitive, Etransitive.transitiveAny]
curProp.person = [Eperson.first, Eperson.second, Eperson.third, Eperson.personAny]
curProp.tense = [Etense.infinitive, Etense.present, Etense.past, Etense.future, Etense.imperative, Etense.tenseAny]
curProp.voice = [Evoice.active, Evoice.passive, Evoice.voiceAny]
curProp.degree = [Edegree.strong, Edegree.weak, Edegree.degreeAny]
curProp.static = [True, False]
properties[Es_cl.predicative] = curProp

# %%
#particle (частица)
curProp = PropertyPartSpeech()
curProp.s_cl = Es_cl.particle
curProp.animate = [Eanimate.animateAny]
curProp.gender = [Egender.genderAny]
curProp.number = [Enumber.numberAny]
curProp.case1 = [Ecase.caseAny]
curProp.ref1ection = [Ereflection.reflectionAny]
curProp.perfective = [Eperfective.perfectiveAny]
curProp.transitive = [Etransitive.transitiveAny]
curProp.person = [Eperson.personAny]
curProp.tense = [Etense.tenseAny]
curProp.voice = [Evoice.voiceAny]
curProp.degree = [Edegree.degreeAny]
curProp.static = [True]
properties[Es_cl.particle] = curProp

# %%
#interjection (междометие)
curProp = PropertyPartSpeech()
curProp.s_cl = Es_cl.interjection
curProp.animate = [Eanimate.animateAny]
curProp.gender = [Egender.genderAny]
curProp.number = [Enumber.numberAny]
curProp.case1 = [Ecase.caseAny]
curProp.ref1ection = [Ereflection.reflectionAny]
curProp.perfective = [Eperfective.perfectiveAny]
curProp.transitive = [Etransitive.transitiveAny]
curProp.person = [Eperson.personAny]
curProp.tense = [Etense.tenseAny]
curProp.voice = [Evoice.voiceAny]
curProp.degree = [Edegree.degreeAny]
curProp.static = [True]
properties[Es_cl.interjection] = curProp

# %%
# не выполнять

# %%
#acronym
# нет в базе
curProp = PropertyPartSpeech()
curProp.s_cl = Es_cl.acronym
curProp.animate = [Eanimate.animate, Eanimate.unanimate, Eanimate.animateAny]
curProp.gender = [Egender.male, Egender.female, Egender.neuter, Egender.malefemale, Egender.maleorfemale, Egender.genderAny]
curProp.number = [Enumber.single, Enumber.plural, Enumber.numberAny]
curProp.case1 = [Ecase.nominative, Ecase.genitive, Ecase.dative, Ecase.accusative, Ecase.instrumental, Ecase.prepositional, Ecase.caseAny]
curProp.ref1ection = [Ereflection.reflexive, Ereflection.unreflexive, Ereflection.reflexiveForm, Ereflection.reflectionAny]
curProp.perfective = [Eperfective.perfective, Eperfective.unperfective, Eperfective.perfectiveAny]
curProp.transitive = [Etransitive.transitive, Etransitive.untransitive, Etransitive.transitiveAny]
curProp.person = [Eperson.first, Eperson.second, Eperson.third, Eperson.personAny]
curProp.tense = [Etense.infinitive, Etense.present, Etense.past, Etense.future, Etense.imperative, Etense.tenseAny]
curProp.voice = [Evoice.active, Evoice.passive, Evoice.voiceAny]
curProp.degree = [Edegree.strong, Edegree.weak, Edegree.degreeAny]
curProp.static = [True, False]
properties[Es_cl.acronym] = curProp

# %%
curProp = PropertyPartSpeech()
properties['S_clAny'] = curProp

# %%
len(properties)
# Out:
# 29

# %%
# переборная модель
curProp = PropertyPartSpeech()
curProp.s_cl = Es_cl.possesiveadjective
curProp.animate = [Eanimate.animate, Eanimate.unanimate, Eanimate.animateAny]
curProp.gender = [Egender.male, Egender.female, Egender.neuter, Egender.malefemale, Egender.maleorfemale, Egender.genderAny]
curProp.number = [Enumber.single, Enumber.plural, Enumber.numberAny]
curProp.case1 = [Ecase.nominative, Ecase.genitive, Ecase.dative, Ecase.accusative, Ecase.instrumental, Ecase.prepositional, Ecase.caseAny]
curProp.ref1ection = [Ereflection.reflexive, Ereflection.unreflexive, Ereflection.reflexiveForm, Ereflection.reflectionAny]
curProp.perfective = [Eperfective.perfective, Eperfective.unperfective, Eperfective.perfectiveAny]
curProp.transitive = [Etransitive.transitive, Etransitive.untransitive, Etransitive.transitiveAny]
curProp.person = [Eperson.first, Eperson.second, Eperson.third, Eperson.personAny]
curProp.tense = [Etense.infinitive, Etense.present, Etense.past, Etense.future, Etense.imperative, Etense.tenseAny]
curProp.voice = [Evoice.active, Evoice.passive, Evoice.voiceAny]
curProp.degree = [Edegree.strong, Edegree.weak, Edegree.degreeAny]
curProp.static = [True, False]
properties[Es_cl.possesiveadjective] = curProp
